# %% [markdown]
# # **Пример использования Markdown**
#
# ### Нужно сделать:
#
# 1.   Список.
# 2.   Рисунок.
# 3.   Таблицу.
# 4.   Ссылку.
#
#
# ![Вовка!](https://www.dialog.ua/images/news/news_view/3f7069e618fdd82c7922243c11bd58d5.jpg)
#
# [**Владимир Путин молодец!**](http://positime.ru/wp-content/uploads/2015/12/Vladimir_Putin_12023.jpg)
#
#
# | Бригада
#  -------------
#      2 человека
#    2 мужика
# 2 ЗОЖника
